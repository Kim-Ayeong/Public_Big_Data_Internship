# %% [markdown]
# import requests
# url = "https://www.naver.com"
#
# response = requests.post(url, auth=("NAVER_ID","NAVER_PASS"))
#
# print("status code :", response.status_code)

# %% [markdown]
# ## 네이버 정상 접속 예시

# %%
import requests 

url = "https://www.naver.com" 
rs = requests.post(url) 

# response code 
응답코드 = rs.status_code 

if int(응답코드) == 200 : 
    print("Okay") 
    응답텍스트 = rs.text 
    print(응답텍스트) 
else : 
    print(응답코드) 
    print("Fail")
# Out:
# Okay
#
# ...

# %% [markdown]
# ###### sysdm.cpl에 NAVER_ID, NAVER_PASS 설정

# %% [markdown]
# ## 벅스차트 예시

# %% [markdown]
# https://hongku.tistory.com/292

# %%
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import re

req = requests.get('https://music.bugs.co.kr/chart')
html = req.content
soup = BeautifulSoup(html, 'lxml') # pip install lxml
list_song = soup.find_all(name="p", attrs={"class":"title"})
list_artist = soup.find_all(name="p", attrs={"class":"artist"})

# 곡명 추출
for index in range(0, len(list_song)):
    title = list_song[index].find('a').text
    print(index+1, ' : ', title)
    if index == 100:
        break

# 피처링 제거
for index in range(0, len(list_song)):
    title = list_song[index].find('a').text
    print(index+1, ' : ', title.split("(")[0])
    if index == 100:
        break

# csv로 저장
import csv

with open('melon_chart.csv', 'w', encoding='utf-8-sig') as file:
    writer = csv.writer(file, delimiter=',')
    writer.writerow(['rank', 'song', 'artist'])
    for index in range(0, len(list_song)):
        title = list_song[index].find('a').text
        artist = list_artist[index].find('a').text
        writer.writerow([index+1, title, artist])
        if index == 100:
            break

# 저장된 파일 pd로 읽기
import pandas as pd
datas = pd.read_csv('melon_chart.csv')
# Out:
# 1  :  다시 여기 바닷가
# 2  :  마리아 (Maria)
# 3  :  How You Like That
# 4  :  여름 안에서 by 싹쓰리 (Feat. 황광희)
# 5  :  바다
# 6  :  Summer Hate (Feat. 비)
# 7  :  보라빛 밤 (pporappippam)
# 8  :  OHIO
# 9  :  PLAY (Feat. 창모)
# 10  :  Monster
# 11  :  Dolphin
# 12  :  에잇(Prod.&Feat. SUGA of BTS)
# 13  :  Downtown Baby
# 14  :  아직 너의 시간에 살아
# 15  :  살짝 설렜어 (Nonstop)
# 16  :  취기를 빌려 (취향저격 그녀 X 산들)
# 17  :  아로하
# 18  :  Apple
# 19  :  Into the I-LAND
# 20  :  MORE & MORE
# 21  :  사랑하게 될 줄 알았어
# 22  :  Dance Monkey
# 23  :  Memories
# 24  :  나도 모르는 노래 (Hallelujah)
# 25  :  Blueming
# 26  :  흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 27  :  You're Cold (더 많이 사랑한 쪽이 아프대)
# 28  :  Psycho
# 29  :  환상동화 (Secret Story of the Swan)
# 30  :  어떻게 지내 (Prod. By VAN.C)
# 31  :  METEOR
# 32  :  숨 (Breath)
# 33  :  아무노래
# 34  :  Juice
# 35  :  품
# 36  :  나비와 고양이 (feat. 백현 (BAEKHYUN))
# 37  :  Don't Start Now
# 38  :  좋은 사람 있으면 소개시켜줘
# 39  :  Maniac
# 40  :  너에게 난, 나에게 넌
# 41  :  2002
# 42  :  Error (Feat. Loopy)
# 43  :  LALALILALA
# ...
