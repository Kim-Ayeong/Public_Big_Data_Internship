# %% [markdown]
# https://heodolf.tistory.com/80

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
 
URL = 'http://deal.11st.co.kr/html/nc/deal/main.html'
DRIVER_PATH = 'chromedriver.exe'
 
chrome_options = Options()
chrome_options.add_argument( '--headless' )
chrome_options.add_argument( '--log-level=3' )
chrome_options.add_argument( '--disable-logging' )
chrome_options.add_argument( '--no-sandbox' )
chrome_options.add_argument( '--disable-gpu' )
 
driver = webdriver.Chrome( executable_path=DRIVER_PATH, chrome_options=chrome_options )
driver.get( URL )
 
elements = driver.find_elements_by_css_selector('#emergencyPrd > div > ul > li')
 
print( '상품 개수: {}'.format( len(elements) ) )
for el in elements:
    el_title = el.find_element_by_css_selector('div > a > div.prd_info > p > span.fs_16')
    el_price = el.find_element_by_css_selector('div > a > div.prd_info > div > span.price_detail > strong')
 
    tagName = el_title.tag_name
    className = el_title.get_attribute('class')
    title = el_title.text
    price = el_price.text
    
    print( '='*50 )
    print( 'tagName: {}'.format( tagName ) )
    print( 'className: {}'.format( className ) )
    print( 'title: {}'.format( title ) )
    print( 'price: {}'.format( price ) )
# Out:
# 상품 개수: 24
# ==================================================
# tagName: span
# className: fs_16
# title: [런칭특.가54만]HP OMEN 27i 27인치 165Hz QHD 게이밍모니터 (1ms 나노IPS 350nits 지싱크호환 3년A/S)
# price: 569,000
# ==================================================
# tagName: span
# className: fs_16
# title: [와룡식품본사직영]와룡막창 참나무 초벌 훈제 막창/양념 곱창/목살+와룡 막장소스 선택
# price: 11,900
# ==================================================
# tagName: span
# className: fs_16
# title: [SK매직공식인증점] SK매직 렌탈 정수기 상품권20만/공기청정기/비데/직수/얼음정수기
# price: 16,900
# ==================================================
# tagName: span
# className: fs_16
# title: [코렐 BIG SALE] 스누피 에디션 외 인기만점 식기 아이템 BEST 총집합
# price: 12,500
# ==================================================
# tagName: span
# className: fs_16
# title: 25%쿠폰!아우라 안심유연제 초고농축 5.5Lx2개 미세플라스틱Free
# price: 31,900
# ==================================================
# tagName: span
# className: fs_16
# title: [10%+20%] 온더바디 발을씻자 풋 샴푸 385mlx3개+온더바디워시180g증정
# price: 13,500
# ==================================================
# tagName: span
# className: fs_16
# title: SK매직 식기세척기DWA-8000D 터치온 12인용 자동문열림
# price: 890,000
# ==================================================
# tagName: span
# className: fs_16
# title: [18%+10%중복쿠폰][고양이]로얄캐닌사료전종모음/인도어/키튼/헤어볼/샴/페르시안/뱅갈/노르웨이숲
# price: 30,000
# ==================================================
# tagName: span
# className: fs_16
# title: [20%+17%+T11%]뷰티2관왕! 1+1+1 썬크림 트리플 세일, 전품목 BIG SALE!
# price: 9,900
# ==================================================
# tagName: span
# className: fs_16
# title: [7월 추천 생선회] MAP포장으로 신선한 숙성 생선회 모음 + 소스 3종(회초장/생와사비/간장)
# price: 6,900
# ==================================================
# tagName: span
# className: fs_16
# title: 갤럭시 노트9 (재출시) 128G
# price: 799,700
# ==================================================
# tagName: span
# className: fs_16
# title: 캐치웰 3in1 CR3 물걸레 로봇청소기 실버색상+2년무상AS
# price: 159,000
# ==================================================
# tagName: span
# className: fs_16
# title: [오늘만! 30%+T11%][에스콰이아] 11번가 단독! 여름 데일리 BAG/에코백/미니백/토트백 외 UP TO ~86% OFF
# price: 13,900
# ==================================================
# tagName: span
# className: fs_16
# title: 더 순수 퍼플 3겹 천연펄프 화장지 27m 30롤 x 2팩
# price: 27,900
# ==================================================
# tagName: span
# className: fs_16
# title: [혜택가 7,440원] 11%+T멤버십22%혜택! 윙블링 셀럽쥬얼리+복수구매할인(7/22일 단하루)
# price: 10,700
# ==================================================
# tagName: span
# className: fs_16
# title: [7/22 20%+15%쿠폰]무로 바라나스 요가링1박스(2개입),마사지스틱,요가매트,마사지볼 모음전
# price: 13,500
# ==================================================
# tagName: span
# className: fs_16
# title: 최종혜택 4,800부터 쥬드 후기극찬 수제 베스트 샌들 클리어런스/웨지힐/쪼리/블로퍼/플리플롭/슬링백샌들
# price: 16,500
# ==================================================
# tagName: span
# className: fs_16
# title: 2020 S/S 크록스 크록밴드 키즈/성인 클로그 모음전!
# price: 17,800
# ==================================================
# tagName: span
# className: fs_16
# title: [10%+11%+22%T][르젠]시원한 여름 스타일 남성코디 모음전 슬랙스/반팔티/린넨셔츠/반바지/린넨바지/오버핏
# price: 9,900
# ==================================================
# tagName: span
# className: fs_16
# title: [런칭 단독 특가 상품권 증정] 삼성 JBL BAR 9.1 돌비애트모스 블루투스 사운드바 홈시어터 TV사운드바
# price: 1,390,000
# ==================================================
# tagName: span
# className: fs_16
# title: [미니멜츠] 구슬아이스크림 18개 골라담기! (텐더초코/소프트베리/스윗멜로우/레인보우아이스)
# price: 17,500
# ==================================================
# tagName: span
# className: fs_16
# title: [추가15%][오뚜기] 맛있는 오뚜기밥 210g x 24개 외 5종
# price: 19,750
# ==================================================
# tagName: span
# className: fs_16
# title: [오뚜기_맛남의 광장]완도 청정 다시마 2개 오동통면外 진라면/진비빔면/진진짜라등 BEST / 착한 라면
# price: 10,440
# ==================================================
# tagName: span
# className: fs_16
# title: 바닐라코 G리는 썸머세일 전품목 1+1 & 최대 70% 할인
# price: 10,000
